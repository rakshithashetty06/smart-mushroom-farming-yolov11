# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls /content
# Out:
# drive  sample_data

# %%
# %cd /content/drive/MyDrive
# Out:
# /content/drive/MyDrive

# %%
# !ls
# Out:
# 'Colab Notebooks'   intership	 techtern	  'yolo 11'
#  intern_3	    intership2	 Untitled3.ipynb

# %%
# !ls
# Out:
# 'Colab Notebooks'   intership	 techtern	  'yolo 11'
#  intern_3	    intership2	 Untitled3.ipynb

# %%
# !ls /content
# Out:
#  drive	 sample_data  'yolo 11'

# %%
# !rm -rf "/content/yolo 11"

# %%
# !ls /content
# Out:
# drive  sample_data

# %%
# %cd yolo 11
# Out:
# /content/drive/MyDrive/yolo 11

# %%
# !ls
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  train  valid

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 63.1 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=train model=yolo11s.pt data=data.yaml epochs=120 patience=50 imgsz=800 hsv_h=0.02 hsv_s=0.7 hsv_v=0.4 degrees=10 translate=0.1 scale=0.5 shear=2
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.4.21 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...
